# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score

# Make grid
def make_grid(points, xlim, ylim, n_x, n_y):

    xs = np.linspace(xlim[0], xlim[1], n_x + 1)
    ys = np.linspace(ylim[0], ylim[1], n_y + 1)

    # digitize returns [1, len(xs)], so subtract 1
    xi = np.clip(np.digitize(points[:, 0], xs) - 1, 0, n_x - 1)
    yi = np.clip(np.digitize(points[:, 1], ys) - 1, 0, n_y - 1)

    H = np.zeros((n_x, n_y), dtype=float)
    np.add.at(H, (xi, yi), 1)
    return H, xs, ys

# Add Laplace noises
def laplace_mech(counts, epsilon, clip_zero=True, rng=None):
    if rng is None:
        rng = np.random.default_rng()
    b = 1.0 / float(epsilon)
    noise = rng.laplace(loc=0.0, scale=b, size=counts.shape)
    out = counts + noise
    if clip_zero:
        out = np.maximum(out, 0.0)
    return out, noise

# Connect components to spans
def spans_from_noisy(noisy, threshold_T):
    active = noisy >= threshold_T
    visited = np.zeros_like(active, dtype=bool)
    spans = []

    n_x, n_y = active.shape

    for i in range(n_x):
        for j in range(n_y):
            if active[i, j] and not visited[i, j]:
                stack = [(i, j)]
                visited[i, j] = True
                xs = [i]
                ys = [j]

                while stack:
                    x, y = stack.pop()
                    for dx, dy in [(1, 0), (-1, 0), (0, 1), (0, -1)]:
                        xx, yy = x + dx, y + dy
                        if 0 <= xx < n_x and 0 <= yy < n_y:
                            if active[xx, yy] and not visited[xx, yy]:
                                visited[xx, yy] = True
                                stack.append((xx, yy))
                                xs.append(xx)
                                ys.append(yy)

                spans.append((min(xs), min(ys), max(xs), max(ys)))

    return spans

# Convert span indices (cell indices) into continuous coordinates (x_min, y_min, x_max, y_max)
def boxes_to_world(spans, xs, ys):
    dx, dy = xs[1] - xs[0], ys[1] - ys[0]
    world = []
    for (x1, y1, x2, y2) in spans:
        world.append((xs[x1], ys[y1], xs[x2] + dx, ys[y2] + dy))
    return world

# Assign labels according to spans
def assign_labels_from_spans(points, spans_world):
    labels = np.full(len(points), -1, dtype=int)
    for k, (xmin, ymin, xmax, ymax) in enumerate(spans_world):
        mask = (
            (points[:, 0] >= xmin) & (points[:, 0] < xmax) &
            (points[:, 1] >= ymin) & (points[:, 1] < ymax)
        )
        labels[mask] = k
    return labels

# Evaluation based on AMI and ARI
def evaluate_dp_params(X, eps_priv, T, n_x, n_y, db_eps, db_min):
    # Grid counts
    H, xs, ys = make_grid(
        X,
        (X[:, 0].min(), X[:, 0].max()),
        (X[:, 1].min(), X[:, 1].max()),
        n_x=n_x,
        n_y=n_y
    )

    # DP noise
    noisy, _ = laplace_mech(H, epsilon=eps_priv, clip_zero=True)

    # Spans from thresholded noisy grid
    spans = spans_from_noisy(noisy, threshold_T=T)
    spans_world = boxes_to_world(spans, xs, ys)
    y_pred = assign_labels_from_spans(X, spans_world)

    # Ground-truth clustering (non-private)
    y_true = DBSCAN(eps=db_eps, min_samples=db_min).fit_predict(X)

    # Compute AMI & ARI only on points that have labels in both
    idx = (y_true != -1) & (y_pred != -1)
    if idx.any():
        AMI = adjusted_mutual_info_score(y_true[idx], y_pred[idx])
        ARI = adjusted_rand_score(y_true[idx], y_pred[idx])
    else:
        AMI = 0.0
        ARI = 0.0

    return AMI, ARI, spans, xs, ys, noisy


# Grid Search and optimize by AMI and ARI
if __name__ == "__main__":
    X, _ = make_blobs(n_samples=2000, random_state=0)


    # grid + counts
    H, xs, ys = make_grid(X, (X[:,0].min(), X[:,0].max()),
                         (X[:,1].min(), X[:,1].max()),
                         n_x=64, n_y=64)

    # noise with different eps
    noisy1, _ = laplace_mech(H, epsilon=4, clip_zero=True)       
    noisy2, _ = laplace_mech(H, epsilon=0.5, clip_zero=True)

    # plot
    fig, axs = plt.subplots(1,3, figsize=(12,3.5))
    axs[0].imshow(H.T, origin='lower', aspect='auto'); axs[0].set_title('True counts')
    axs[1].imshow(noisy1.T, origin='lower', aspect='auto'); axs[1].set_title('Noisy (ε=2.0)')
    axs[2].imshow(noisy2.T, origin='lower', aspect='auto'); axs[2].set_title('Noisy (ε=0.5)')
    for ax in axs: ax.axis('off')
    plt.tight_layout(); plt.show()

    # search space:
    eps_candidates = [0.3, 0.5, 1.0, 2.0, 3.5, 4.0]
    T_candidates = [1.0, 1.5, 1.7, 2.0, 2.5]
    grid_sizes = [(32, 32), (48, 48), (64, 64)]
    dbscan_eps_vals = [0.15, 0.20, 0.25]
    dbscan_min_vals = [5, 10, 15]

    best_ari = -1.0
    best_conf = None
    best_outputs = None
    best_ami_for_best_ari = None

    print("Parameter Search (Optimizing ARI, reporting AMI+ARI) from here: ")

    for eps_priv in eps_candidates:
        for T in T_candidates:
            for nx, ny in grid_sizes:
                for dbe in dbscan_eps_vals:
                    for dbm in dbscan_min_vals:

                        AMI, ARI, spans, xs, ys, noisy = evaluate_dp_params(
                            X, eps_priv, T, nx, ny, dbe, dbm
                        )

                        print(
                            f"eps={eps_priv:.2f}, T={T:.2f}, "
                            f"grid={nx}x{ny}, DBSCAN={dbe}/{dbm} "
                            f"--> AMI={AMI:.3f}, ARI={ARI:.3f}"
                        )

                        # Optimization criterion: maximize ARI
                        if ARI > best_ari:
                            best_ari = ARI
                            best_ami_for_best_ari = AMI
                            best_conf = (eps_priv, T, nx, ny, dbe, dbm)
                            best_outputs = (spans, xs, ys, noisy)

    print("\n=== BEST PARAMETERS (by ARI) ===")
    eps_priv, T, nx, ny, dbe, dbm = best_conf
    print(f"Epsilon (privacy):      {eps_priv}")
    print(f"Threshold T:            {T}")
    print(f"Grid size:              {nx} x {ny}")
    print(f"DBSCAN eps / min_samp:  {dbe} / {dbm}")
    print(f"Best ARI:               {best_ari:.4f}")
    print(f"AMI at best ARI:        {best_ami_for_best_ari:.4f}")
# Out:
# Parameter Search (Optimizing ARI, reporting AMI+ARI) from here:
# eps=0.30, T=1.00, grid=32x32, DBSCAN=0.15/5 --> AMI=0.018, ARI=0.004
# eps=0.30, T=1.00, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.00, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.00, grid=32x32, DBSCAN=0.2/5 --> AMI=0.071, ARI=0.080
# eps=0.30, T=1.00, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.00, grid=32x32, DBSCAN=0.2/15 --> AMI=0.024, ARI=0.004
# eps=0.30, T=1.00, grid=32x32, DBSCAN=0.25/5 --> AMI=-0.006, ARI=-0.011
# eps=0.30, T=1.00, grid=32x32, DBSCAN=0.25/10 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.00, grid=32x32, DBSCAN=0.25/15 --> AMI=0.107, ARI=0.055
# eps=0.30, T=1.00, grid=48x48, DBSCAN=0.15/5 --> AMI=0.517, ARI=0.445
# eps=0.30, T=1.00, grid=48x48, DBSCAN=0.15/10 --> AMI=0.109, ARI=0.012
# eps=0.30, T=1.00, grid=48x48, DBSCAN=0.15/15 --> AMI=0.487, ARI=0.425
# eps=0.30, T=1.00, grid=48x48, DBSCAN=0.2/5 --> AMI=0.155, ARI=0.033
# eps=0.30, T=1.00, grid=48x48, DBSCAN=0.2/10 --> AMI=0.168, ARI=0.099
# eps=0.30, T=1.00, grid=48x48, DBSCAN=0.2/15 --> AMI=0.156, ARI=0.008
# eps=0.30, T=1.00, grid=48x48, DBSCAN=0.25/5 --> AMI=0.046, ARI=0.009
# eps=0.30, T=1.00, grid=48x48, DBSCAN=0.25/10 --> AMI=0.284, ARI=0.336
# eps=0.30, T=1.00, grid=48x48, DBSCAN=0.25/15 --> AMI=0.000, ARI=-0.002
# eps=0.30, T=1.00, grid=64x64, DBSCAN=0.15/5 --> AMI=0.486, ARI=0.290
# eps=0.30, T=1.00, grid=64x64, DBSCAN=0.15/10 --> AMI=0.436, ARI=0.117
# eps=0.30, T=1.00, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=0.30, T=1.00, grid=64x64, DBSCAN=0.2/5 --> AMI=0.234, ARI=0.140
# eps=0.30, T=1.00, grid=64x64, DBSCAN=0.2/10 --> AMI=0.511, ARI=0.341
# eps=0.30, T=1.00, grid=64x64, DBSCAN=0.2/15 --> AMI=0.563, ARI=0.213
# eps=0.30, T=1.00, grid=64x64, DBSCAN=0.25/5 --> AMI=0.055, ARI=0.009
# eps=0.30, T=1.00, grid=64x64, DBSCAN=0.25/10 --> AMI=0.094, ARI=0.025
# eps=0.30, T=1.00, grid=64x64, DBSCAN=0.25/15 --> AMI=0.528, ARI=0.322
# eps=0.30, T=1.50, grid=32x32, DBSCAN=0.15/5 --> AMI=0.034, ARI=0.008
# eps=0.30, T=1.50, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.50, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.50, grid=32x32, DBSCAN=0.2/5 --> AMI=0.168, ARI=0.161
# eps=0.30, T=1.50, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.50, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.50, grid=32x32, DBSCAN=0.25/5 --> AMI=0.007, ARI=0.008
# eps=0.30, T=1.50, grid=32x32, DBSCAN=0.25/10 --> AMI=0.020, ARI=0.027
# eps=0.30, T=1.50, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.50, grid=48x48, DBSCAN=0.15/5 --> AMI=0.497, ARI=0.292
# eps=0.30, T=1.50, grid=48x48, DBSCAN=0.15/10 --> AMI=0.334, ARI=0.084
# eps=0.30, T=1.50, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.50, grid=48x48, DBSCAN=0.2/5 --> AMI=0.198, ARI=0.084
# eps=0.30, T=1.50, grid=48x48, DBSCAN=0.2/10 --> AMI=0.535, ARI=0.540
# eps=0.30, T=1.50, grid=48x48, DBSCAN=0.2/15 --> AMI=0.552, ARI=0.312
# eps=0.30, T=1.50, grid=48x48, DBSCAN=0.25/5 --> AMI=0.105, ARI=0.092
# eps=0.30, T=1.50, grid=48x48, DBSCAN=0.25/10 --> AMI=0.080, ARI=0.014
# eps=0.30, T=1.50, grid=48x48, DBSCAN=0.25/15 --> AMI=0.655, ARI=0.735
# eps=0.30, T=1.50, grid=64x64, DBSCAN=0.15/5 --> AMI=0.661, ARI=0.453
# eps=0.30, T=1.50, grid=64x64, DBSCAN=0.15/10 --> AMI=0.621, ARI=0.265
# eps=0.30, T=1.50, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=0.30, T=1.50, grid=64x64, DBSCAN=0.2/5 --> AMI=0.104, ARI=0.009
# eps=0.30, T=1.50, grid=64x64, DBSCAN=0.2/10 --> AMI=0.494, ARI=0.224
# eps=0.30, T=1.50, grid=64x64, DBSCAN=0.2/15 --> AMI=0.604, ARI=0.286
# eps=0.30, T=1.50, grid=64x64, DBSCAN=0.25/5 --> AMI=0.035, ARI=0.003
# eps=0.30, T=1.50, grid=64x64, DBSCAN=0.25/10 --> AMI=0.057, ARI=0.002
# eps=0.30, T=1.50, grid=64x64, DBSCAN=0.25/15 --> AMI=0.420, ARI=0.144
# eps=0.30, T=1.70, grid=32x32, DBSCAN=0.15/5 --> AMI=0.067, ARI=0.018
# eps=0.30, T=1.70, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.70, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.70, grid=32x32, DBSCAN=0.2/5 --> AMI=0.207, ARI=0.217
# eps=0.30, T=1.70, grid=32x32, DBSCAN=0.2/10 --> AMI=0.066, ARI=0.029
# eps=0.30, T=1.70, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.70, grid=32x32, DBSCAN=0.25/5 --> AMI=0.097, ARI=0.103
# eps=0.30, T=1.70, grid=32x32, DBSCAN=0.25/10 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.70, grid=32x32, DBSCAN=0.25/15 --> AMI=0.002, ARI=-0.006
# eps=0.30, T=1.70, grid=48x48, DBSCAN=0.15/5 --> AMI=0.256, ARI=0.078
# eps=0.30, T=1.70, grid=48x48, DBSCAN=0.15/10 --> AMI=0.525, ARI=0.204
# eps=0.30, T=1.70, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=0.30, T=1.70, grid=48x48, DBSCAN=0.2/5 --> AMI=0.130, ARI=0.020
# eps=0.30, T=1.70, grid=48x48, DBSCAN=0.2/10 --> AMI=0.655, ARI=0.676
# eps=0.30, T=1.70, grid=48x48, DBSCAN=0.2/15 --> AMI=0.277, ARI=0.078
# eps=0.30, T=1.70, grid=48x48, DBSCAN=0.25/5 --> AMI=0.066, ARI=0.016
# eps=0.30, T=1.70, grid=48x48, DBSCAN=0.25/10 --> AMI=0.088, ARI=0.019
# eps=0.30, T=1.70, grid=48x48, DBSCAN=0.25/15 --> AMI=0.697, ARI=0.803
# eps=0.30, T=1.70, grid=64x64, DBSCAN=0.15/5 --> AMI=0.572, ARI=0.289
# eps=0.30, T=1.70, grid=64x64, DBSCAN=0.15/10 --> AMI=0.627, ARI=0.324
# eps=0.30, T=1.70, grid=64x64, DBSCAN=0.15/15 --> AMI=0.390, ARI=0.277
# eps=0.30, T=1.70, grid=64x64, DBSCAN=0.2/5 --> AMI=0.118, ARI=0.011
# eps=0.30, T=1.70, grid=64x64, DBSCAN=0.2/10 --> AMI=0.494, ARI=0.295
# eps=0.30, T=1.70, grid=64x64, DBSCAN=0.2/15 --> AMI=0.677, ARI=0.406
# eps=0.30, T=1.70, grid=64x64, DBSCAN=0.25/5 --> AMI=0.038, ARI=0.007
# eps=0.30, T=1.70, grid=64x64, DBSCAN=0.25/10 --> AMI=0.056, ARI=0.005
# eps=0.30, T=1.70, grid=64x64, DBSCAN=0.25/15 --> AMI=0.374, ARI=0.145
# eps=0.30, T=2.00, grid=32x32, DBSCAN=0.15/5 --> AMI=0.000, ARI=0.000
# eps=0.30, T=2.00, grid=32x32, DBSCAN=0.15/10 --> AMI=0.020, ARI=0.002
# eps=0.30, T=2.00, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=0.30, T=2.00, grid=32x32, DBSCAN=0.2/5 --> AMI=0.238, ARI=0.257
# eps=0.30, T=2.00, grid=32x32, DBSCAN=0.2/10 --> AMI=0.023, ARI=0.012
# eps=0.30, T=2.00, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=0.30, T=2.00, grid=32x32, DBSCAN=0.25/5 --> AMI=0.167, ARI=0.205
# eps=0.30, T=2.00, grid=32x32, DBSCAN=0.25/10 --> AMI=-0.008, ARI=-0.029
# eps=0.30, T=2.00, grid=32x32, DBSCAN=0.25/15 --> AMI=0.095, ARI=0.039
# eps=0.30, T=2.00, grid=48x48, DBSCAN=0.15/5 --> AMI=0.605, ARI=0.476
# eps=0.30, T=2.00, grid=48x48, DBSCAN=0.15/10 --> AMI=0.075, ARI=0.005
# eps=0.30, T=2.00, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=0.30, T=2.00, grid=48x48, DBSCAN=0.2/5 --> AMI=0.157, ARI=0.038
# eps=0.30, T=2.00, grid=48x48, DBSCAN=0.2/10 --> AMI=0.625, ARI=0.526
# eps=0.30, T=2.00, grid=48x48, DBSCAN=0.2/15 --> AMI=0.637, ARI=0.417
# eps=0.30, T=2.00, grid=48x48, DBSCAN=0.25/5 --> AMI=0.038, ARI=0.005
# eps=0.30, T=2.00, grid=48x48, DBSCAN=0.25/10 --> AMI=0.081, ARI=0.005
# eps=0.30, T=2.00, grid=48x48, DBSCAN=0.25/15 --> AMI=0.576, ARI=0.520
# eps=0.30, T=2.00, grid=64x64, DBSCAN=0.15/5 --> AMI=0.602, ARI=0.413
# eps=0.30, T=2.00, grid=64x64, DBSCAN=0.15/10 --> AMI=0.647, ARI=0.255
# eps=0.30, T=2.00, grid=64x64, DBSCAN=0.15/15 --> AMI=0.650, ARI=0.492
# eps=0.30, T=2.00, grid=64x64, DBSCAN=0.2/5 --> AMI=0.093, ARI=0.008
# eps=0.30, T=2.00, grid=64x64, DBSCAN=0.2/10 --> AMI=0.509, ARI=0.270
# eps=0.30, T=2.00, grid=64x64, DBSCAN=0.2/15 --> AMI=0.667, ARI=0.419
# eps=0.30, T=2.00, grid=64x64, DBSCAN=0.25/5 --> AMI=0.037, ARI=0.005
# eps=0.30, T=2.00, grid=64x64, DBSCAN=0.25/10 --> AMI=0.069, ARI=0.011
# eps=0.30, T=2.00, grid=64x64, DBSCAN=0.25/15 --> AMI=0.418, ARI=0.177
# eps=0.30, T=2.50, grid=32x32, DBSCAN=0.15/5 --> AMI=0.043, ARI=0.008
# eps=0.30, T=2.50, grid=32x32, DBSCAN=0.15/10 --> AMI=0.019, ARI=0.002
# eps=0.30, T=2.50, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=0.30, T=2.50, grid=32x32, DBSCAN=0.2/5 --> AMI=0.337, ARI=0.324
# eps=0.30, T=2.50, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=-0.009
# eps=0.30, T=2.50, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=0.30, T=2.50, grid=32x32, DBSCAN=0.25/5 --> AMI=0.189, ARI=0.190
# eps=0.30, T=2.50, grid=32x32, DBSCAN=0.25/10 --> AMI=0.053, ARI=0.054
# eps=0.30, T=2.50, grid=32x32, DBSCAN=0.25/15 --> AMI=-0.000, ARI=-0.003
# eps=0.30, T=2.50, grid=48x48, DBSCAN=0.15/5 --> AMI=0.572, ARI=0.329
# eps=0.30, T=2.50, grid=48x48, DBSCAN=0.15/10 --> AMI=0.464, ARI=0.131
# eps=0.30, T=2.50, grid=48x48, DBSCAN=0.15/15 --> AMI=0.851, ARI=0.882
# eps=0.30, T=2.50, grid=48x48, DBSCAN=0.2/5 --> AMI=0.081, ARI=0.008
# eps=0.30, T=2.50, grid=48x48, DBSCAN=0.2/10 --> AMI=0.526, ARI=0.329
# eps=0.30, T=2.50, grid=48x48, DBSCAN=0.2/15 --> AMI=0.541, ARI=0.282
# eps=0.30, T=2.50, grid=48x48, DBSCAN=0.25/5 --> AMI=0.031, ARI=0.006
# eps=0.30, T=2.50, grid=48x48, DBSCAN=0.25/10 --> AMI=0.053, ARI=0.003
# eps=0.30, T=2.50, grid=48x48, DBSCAN=0.25/15 --> AMI=0.505, ARI=0.263
# eps=0.30, T=2.50, grid=64x64, DBSCAN=0.15/5 --> AMI=0.641, ARI=0.318
# eps=0.30, T=2.50, grid=64x64, DBSCAN=0.15/10 --> AMI=0.712, ARI=0.364
# eps=0.30, T=2.50, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=0.30, T=2.50, grid=64x64, DBSCAN=0.2/5 --> AMI=0.092, ARI=0.008
# eps=0.30, T=2.50, grid=64x64, DBSCAN=0.2/10 --> AMI=0.420, ARI=0.105
# eps=0.30, T=2.50, grid=64x64, DBSCAN=0.2/15 --> AMI=0.754, ARI=0.573
# eps=0.30, T=2.50, grid=64x64, DBSCAN=0.25/5 --> AMI=0.017, ARI=0.001
# eps=0.30, T=2.50, grid=64x64, DBSCAN=0.25/10 --> AMI=0
# eps=1.00, T=2.50, grid=48x48, DBSCAN=0.25/5 --> AMI=0.031, ARI=0.006
# eps=1.00, T=2.50, grid=48x48, DBSCAN=0.25/10 --> AMI=0.081, ARI=0.015
# eps=1.00, T=2.50, grid=48x48, DBSCAN=0.25/15 --> AMI=0.636, ARI=0.599
# eps=1.00, T=2.50, grid=64x64, DBSCAN=0.15/5 --> AMI=0.582, ARI=0.176
# eps=1.00, T=2.50, grid=64x64, DBSCAN=0.15/10 --> AMI=0.866, ARI=0.740
# eps=1.00, T=2.50, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=1.00, T=2.50, grid=64x64, DBSCAN=0.2/5 --> AMI=0.063, ARI=0.005
# eps=1.00, T=2.50, grid=64x64, DBSCAN=0.2/10 --> AMI=0.373, ARI=0.087
# eps=1.00, T=2.50, grid=64x64, DBSCAN=0.2/15 --> AMI=0.736, ARI=0.522
# eps=1.00, T=2.50, grid=64x64, DBSCAN=0.25/5 --> AMI=0.003, ARI=0.000
# eps=1.00, T=2.50, grid=64x64, DBSCAN=0.25/10 --> AMI=0.045, ARI=0.003
# eps=1.00, T=2.50, grid=64x64, DBSCAN=0.25/15 --> AMI=0.321, ARI=0.058
# eps=2.00, T=1.00, grid=32x32, DBSCAN=0.15/5 --> AMI=0.009, ARI=0.002
# eps=2.00, T=1.00, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.00, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.00, grid=32x32, DBSCAN=0.2/5 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.00, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.00, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.00, grid=32x32, DBSCAN=0.25/5 --> AMI=0.078, ARI=0.099
# eps=2.00, T=1.00, grid=32x32, DBSCAN=0.25/10 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.00, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.00, grid=48x48, DBSCAN=0.15/5 --> AMI=0.061, ARI=0.014
# eps=2.00, T=1.00, grid=48x48, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.00, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.00, grid=48x48, DBSCAN=0.2/5 --> AMI=0.355, ARI=0.353
# eps=2.00, T=1.00, grid=48x48, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.00, grid=48x48, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.00, grid=48x48, DBSCAN=0.25/5 --> AMI=0.264, ARI=0.291
# eps=2.00, T=1.00, grid=48x48, DBSCAN=0.25/10 --> AMI=0.335, ARI=0.361
# eps=2.00, T=1.00, grid=48x48, DBSCAN=0.25/15 --> AMI=0.150, ARI=0.059
# eps=2.00, T=1.00, grid=64x64, DBSCAN=0.15/5 --> AMI=0.577, ARI=0.372
# eps=2.00, T=1.00, grid=64x64, DBSCAN=0.15/10 --> AMI=0.359, ARI=0.089
# eps=2.00, T=1.00, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=2.00, T=1.00, grid=64x64, DBSCAN=0.2/5 --> AMI=0.182, ARI=0.043
# eps=2.00, T=1.00, grid=64x64, DBSCAN=0.2/10 --> AMI=0.724, ARI=0.785
# eps=2.00, T=1.00, grid=64x64, DBSCAN=0.2/15 --> AMI=0.372, ARI=0.139
# eps=2.00, T=1.00, grid=64x64, DBSCAN=0.25/5 --> AMI=0.071, ARI=0.024
# eps=2.00, T=1.00, grid=64x64, DBSCAN=0.25/10 --> AMI=0.157, ARI=0.072
# eps=2.00, T=1.00, grid=64x64, DBSCAN=0.25/15 --> AMI=0.663, ARI=0.700
# eps=2.00, T=1.50, grid=32x32, DBSCAN=0.15/5 --> AMI=0.024, ARI=0.005
# eps=2.00, T=1.50, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.50, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.50, grid=32x32, DBSCAN=0.2/5 --> AMI=0.047, ARI=0.051
# eps=2.00, T=1.50, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.50, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.50, grid=32x32, DBSCAN=0.25/5 --> AMI=0.139, ARI=0.153
# eps=2.00, T=1.50, grid=32x32, DBSCAN=0.25/10 --> AMI=-0.001, ARI=-0.001
# eps=2.00, T=1.50, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.50, grid=48x48, DBSCAN=0.15/5 --> AMI=0.204, ARI=0.040
# eps=2.00, T=1.50, grid=48x48, DBSCAN=0.15/10 --> AMI=0.317, ARI=0.078
# eps=2.00, T=1.50, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.50, grid=48x48, DBSCAN=0.2/5 --> AMI=0.414, ARI=0.406
# eps=2.00, T=1.50, grid=48x48, DBSCAN=0.2/10 --> AMI=0.205, ARI=0.087
# eps=2.00, T=1.50, grid=48x48, DBSCAN=0.2/15 --> AMI=0.001, ARI=0.000
# eps=2.00, T=1.50, grid=48x48, DBSCAN=0.25/5 --> AMI=0.070, ARI=0.024
# eps=2.00, T=1.50, grid=48x48, DBSCAN=0.25/10 --> AMI=0.193, ARI=0.082
# eps=2.00, T=1.50, grid=48x48, DBSCAN=0.25/15 --> AMI=0.778, ARI=0.867
# eps=2.00, T=1.50, grid=64x64, DBSCAN=0.15/5 --> AMI=0.721, ARI=0.619
# eps=2.00, T=1.50, grid=64x64, DBSCAN=0.15/10 --> AMI=0.620, ARI=0.306
# eps=2.00, T=1.50, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=2.00, T=1.50, grid=64x64, DBSCAN=0.2/5 --> AMI=0.129, ARI=0.022
# eps=2.00, T=1.50, grid=64x64, DBSCAN=0.2/10 --> AMI=0.571, ARI=0.357
# eps=2.00, T=1.50, grid=64x64, DBSCAN=0.2/15 --> AMI=0.687, ARI=0.379
# eps=2.00, T=1.50, grid=64x64, DBSCAN=0.25/5 --> AMI=0.033, ARI=0.005
# eps=2.00, T=1.50, grid=64x64, DBSCAN=0.25/10 --> AMI=0.074, ARI=0.014
# eps=2.00, T=1.50, grid=64x64, DBSCAN=0.25/15 --> AMI=0.536, ARI=0.336
# eps=2.00, T=1.70, grid=32x32, DBSCAN=0.15/5 --> AMI=0.009, ARI=0.002
# eps=2.00, T=1.70, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.70, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.70, grid=32x32, DBSCAN=0.2/5 --> AMI=0.202, ARI=0.195
# eps=2.00, T=1.70, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.70, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.70, grid=32x32, DBSCAN=0.25/5 --> AMI=0.142, ARI=0.142
# eps=2.00, T=1.70, grid=32x32, DBSCAN=0.25/10 --> AMI=-0.001, ARI=-0.001
# eps=2.00, T=1.70, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.70, grid=48x48, DBSCAN=0.15/5 --> AMI=0.534, ARI=0.321
# eps=2.00, T=1.70, grid=48x48, DBSCAN=0.15/10 --> AMI=0.317, ARI=0.078
# eps=2.00, T=1.70, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=1.70, grid=48x48, DBSCAN=0.2/5 --> AMI=0.431, ARI=0.404
# eps=2.00, T=1.70, grid=48x48, DBSCAN=0.2/10 --> AMI=0.712, ARI=0.782
# eps=2.00, T=1.70, grid=48x48, DBSCAN=0.2/15 --> AMI=0.059, ARI=0.009
# eps=2.00, T=1.70, grid=48x48, DBSCAN=0.25/5 --> AMI=0.058, ARI=0.015
# eps=2.00, T=1.70, grid=48x48, DBSCAN=0.25/10 --> AMI=0.163, ARI=0.072
# eps=2.00, T=1.70, grid=48x48, DBSCAN=0.25/15 --> AMI=0.728, ARI=0.803
# eps=2.00, T=1.70, grid=64x64, DBSCAN=0.15/5 --> AMI=0.776, ARI=0.696
# eps=2.00, T=1.70, grid=64x64, DBSCAN=0.15/10 --> AMI=0.729, ARI=0.420
# eps=2.00, T=1.70, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=2.00, T=1.70, grid=64x64, DBSCAN=0.2/5 --> AMI=0.093, ARI=0.010
# eps=2.00, T=1.70, grid=64x64, DBSCAN=0.2/10 --> AMI=0.514, ARI=0.378
# eps=2.00, T=1.70, grid=64x64, DBSCAN=0.2/15 --> AMI=0.728, ARI=0.476
# eps=2.00, T=1.70, grid=64x64, DBSCAN=0.25/5 --> AMI=0.027, ARI=0.003
# eps=2.00, T=1.70, grid=64x64, DBSCAN=0.25/10 --> AMI=0.065, ARI=0.009
# eps=2.00, T=1.70, grid=64x64, DBSCAN=0.25/15 --> AMI=0.424, ARI=0.172
# eps=2.00, T=2.00, grid=32x32, DBSCAN=0.15/5 --> AMI=0.030, ARI=0.006
# eps=2.00, T=2.00, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=2.00, T=2.00, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=2.00, grid=32x32, DBSCAN=0.2/5 --> AMI=0.240, ARI=0.249
# eps=2.00, T=2.00, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=2.00, T=2.00, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=2.00, grid=32x32, DBSCAN=0.25/5 --> AMI=0.193, ARI=0.217
# eps=2.00, T=2.00, grid=32x32, DBSCAN=0.25/10 --> AMI=-0.002, ARI=-0.002
# eps=2.00, T=2.00, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=2.00, grid=48x48, DBSCAN=0.15/5 --> AMI=0.528, ARI=0.320
# eps=2.00, T=2.00, grid=48x48, DBSCAN=0.15/10 --> AMI=0.406, ARI=0.103
# eps=2.00, T=2.00, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=2.00, grid=48x48, DBSCAN=0.2/5 --> AMI=0.188, ARI=0.066
# eps=2.00, T=2.00, grid=48x48, DBSCAN=0.2/10 --> AMI=0.767, ARI=0.818
# eps=2.00, T=2.00, grid=48x48, DBSCAN=0.2/15 --> AMI=0.402, ARI=0.133
# eps=2.00, T=2.00, grid=48x48, DBSCAN=0.25/5 --> AMI=0.053, ARI=0.020
# eps=2.00, T=2.00, grid=48x48, DBSCAN=0.25/10 --> AMI=0.128, ARI=0.053
# eps=2.00, T=2.00, grid=48x48, DBSCAN=0.25/15 --> AMI=0.803, ARI=0.888
# eps=2.00, T=2.00, grid=64x64, DBSCAN=0.15/5 --> AMI=0.636, ARI=0.220
# eps=2.00, T=2.00, grid=64x64, DBSCAN=0.15/10 --> AMI=0.758, ARI=0.400
# eps=2.00, T=2.00, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=2.00, T=2.00, grid=64x64, DBSCAN=0.2/5 --> AMI=0.069, ARI=0.005
# eps=2.00, T=2.00, grid=64x64, DBSCAN=0.2/10 --> AMI=0.383, ARI=0.076
# eps=2.00, T=2.00, grid=64x64, DBSCAN=0.2/15 --> AMI=0.762, ARI=0.566
# eps=2.00, T=2.00, grid=64x64, DBSCAN=0.25/5 --> AMI=0.023, ARI=0.002
# eps=2.00, T=2.00, grid=64x64, DBSCAN=0.25/10 --> AMI=0.058, ARI=0.005
# eps=2.00, T=2.00, grid=64x64, DBSCAN=0.25/15 --> AMI=0.353, ARI=0.088
# eps=2.00, T=2.50, grid=32x32, DBSCAN=0.15/5 --> AMI=0.036, ARI=0.008
# eps=2.00, T=2.50, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=2.00, T=2.50, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=2.50, grid=32x32, DBSCAN=0.2/5 --> AMI=0.290, ARI=0.295
# eps=2.00, T=2.50, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=2.00, T=2.50, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=2.50, grid=32x32, DBSCAN=0.25/5 --> AMI=0.292, ARI=0.323
# eps=2.00, T=2.50, grid=32x32, DBSCAN=0.25/10 --> AMI=0.354, ARI=0.412
# eps=2.00, T=2.50, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=2.00, T=2.50, grid=48x48, DBSCAN=0.15/5 --> AMI=0.638, ARI=0.473
# eps=2.00, T=2.50, grid=48x48, DBSCAN=0.15/10 --> AMI=0.654, ARI=0.337
# eps=2.00, T=2.50, grid=48x48, DBSCAN=0.15/15 --> AMI=0.081, ARI=0.067
# eps=2.00, T=2.50, grid=48x48, DBSCAN=0.2/5 --> AMI=0.144, ARI=0.047
# eps=2.00, T=2.50, grid=48x48, DBSCAN=0.2/10 --> AMI=0.602, ARI=0.421
# eps=2.00, T=2.50, grid=48x48, DBSCAN=0.2/15 --> AMI=0.564, ARI=0.258
# eps=2.00, T=2.50, grid=48x48, DBSCAN=0.25/5 --> AMI=0.039, ARI=0.015
# eps=2.00, T=2.50, grid=48x48, DBSCAN=0.25/10 --> AMI=0.101, ARI=0.023
# eps=2.00, T=2.50, grid=48x48, DBSCAN=0.25/15 --> AMI=0.596, ARI=0.431
# eps=2.00, T=2.50, grid=64x64, DBSCAN=0.15/5 --> AMI=0.557, ARI=0.123
# eps=2.00, T=2.50, grid=64x64, DBSCAN=0.15/10 --> AMI=0.780, ARI=0.435
# eps=2.00, T=2.50, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=2.00, T=2.50, grid=64x64, DBSCAN=0.2/5 --> AMI=0.042, ARI=0.003
# eps=2.00, T=2.50, grid=64x64, DBSCAN=0.2/10 --> AMI=0.322, ARI=0.045
# eps=2.00, T=2.50, grid=64x64, DBSCAN=0.2/15 --> AMI=0.776, ARI=0.545
# eps=2.00, T=2.50, grid=64x64, DBSCAN=0.25/5 --> AMI=0.010, ARI=0.001
# eps=2.00, T=2.50, grid=64x64, DBSCAN=0.25/10 --> AMI=0.034, ARI=0.002
# eps=2.00, T=2.50, grid=64x64, DBSCAN=0.25/15 --> AMI=0.300, ARI=0.046
# eps=3.50, T=1.00, grid=32x32, DBSCAN=0.15/5 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.00, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.00, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.00, grid=32x32, DBSCAN=0.2/5 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.00, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.00, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.00, grid=32x32, DBSCAN=0.25/5 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.00, grid=32x32, DBSCAN=0.25/10 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.00, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.00, grid=48x48, DBSCAN=0.15/5 --> AMI=0.088, ARI=0.018
# eps=3.50, T=1.00, grid=48x48, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.00, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.00, grid=48x48, DBSCAN=0.2/5 --> AMI=0.453, ARI=0.474
# eps=3.50, T=1.00, grid=48x48, DBSCAN=0.2/10 --> AMI=0.101, ARI=0.039
# eps=3.50, T=1.00, grid=48x48, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.00, grid=48x48, DBSCAN=0.25/5 --> AMI=0.287, ARI=0.291
# eps=3.50, T=1.00, grid=48x48, DBSCAN=0.25/10 --> AMI=0.241, ARI=0.244
# eps=3.50, T=1.00, grid=48x48, DBSCAN=0.25/15 --> AMI=0.008, ARI=0.007
# eps=3.50, T=1.00, grid=64x64, DBSCAN=0.15/5 --> AMI=0.659, ARI=0.576
# eps=3.50, T=1.00, grid=64x64, DBSCAN=0.15/10 --> AMI=0.336, ARI=0.084
# eps=3.50, T=1.00, grid=64x64, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.00, grid=64x64, DBSCAN=0.2/5 --> AMI=0.236, ARI=0.104
# eps=3.50, T=1.00, grid=64x64, DBSCAN=0.2/10 --> AMI=0.641, ARI=0.494
# eps=3.50, T=1.00, grid=64x64, DBSCAN=0.2/15 --> AMI=0.372, ARI=0.135
# eps=3.50, T=1.00, grid=64x64, DBSCAN=0.25/5 --> AMI=0.066, ARI=0.021
# eps=3.50, T=1.00, grid=64x64, DBSCAN=0.25/10 --> AMI=0.138, ARI=0.061
# eps=3.50, T=1.00, grid=64x64, DBSCAN=0.25/15 --> AMI=0.746, ARI=0.832
# eps=3.50, T=1.50, grid=32x32, DBSCAN=0.15/5 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.50, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.50, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.50, grid=32x32, DBSCAN=0.2/5 --> AMI=0.088, ARI=0.089
# eps=3.50, T=1.50, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.50, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.50, grid=32x32, DBSCAN=0.25/5 --> AMI=0.126, ARI=0.135
# eps=3.50, T=1.50, grid=32x32, DBSCAN=0.25/10 --> AMI=-0.001, ARI=-0.001
# eps=3.50, T=1.50, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.50, grid=48x48, DBSCAN=0.15/5 --> AMI=0.468, ARI=0.286
# eps=3.50, T=1.50, grid=48x48, DBSCAN=0.15/10 --> AMI=0.317, ARI=0.078
# eps=3.50, T=1.50, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.50, grid=48x48, DBSCAN=0.2/5 --> AMI=0.333, ARI=0.284
# eps=3.50, T=1.50, grid=48x48, DBSCAN=0.2/10 --> AMI=0.717, ARI=0.759
# eps=3.50, T=1.50, grid=48x48, DBSCAN=0.2/15 --> AMI=0.370, ARI=0.133
# eps=3.50, T=1.50, grid=48x48, DBSCAN=0.25/5 --> AMI=0.148, ARI=0.132
# eps=3.50, T=1.50, grid=48x48, DBSCAN=0.25/10 --> AMI=0.184, ARI=0.076
# eps=3.50, T=1.50, grid=48x48, DBSCAN=0.25/15 --> AMI=0.800, ARI=0.871
# eps=3.50, T=1.50, grid=64x64, DBSCAN=0.15/5 --> AMI=0.735, ARI=0.671
# eps=3.50, T=1.50, grid=64x64, DBSCAN=0.15/10 --> AMI=0.614, ARI=0.275
# eps=3.50, T=1.50, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=3.50, T=1.50, grid=64x64, DBSCAN=0.2/5 --> AMI=0.106, ARI=0.017
# eps=3.50, T=1.50, grid=64x64, DBSCAN=0.2/10 --> AMI=0.532, ARI=0.275
# eps=3.50, T=1.50, grid=64x64, DBSCAN=0.2/15 --> AMI=0.617, ARI=0.312
# eps=3.50, T=1.50, grid=64x64, DBSCAN=0.25/5 --> AMI=0.030, ARI=0.005
# eps=3.50, T=1.50, grid=64x64, DBSCAN=0.25/10 --> AMI=0.084, ARI=0.015
# eps=3.50, T=1.50, grid=64x64, DBSCAN=0.25/15 --> AMI=0.469, ARI=0.243
# eps=3.50, T=1.70, grid=32x32, DBSCAN=0.15/5 --> AMI=0.016, ARI=0.004
# eps=3.50, T=1.70, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.70, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.70, grid=32x32, DBSCAN=0.2/5 --> AMI=0.124, ARI=0.126
# eps=3.50, T=1.70, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.70, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.70, grid=32x32, DBSCAN=0.25/5 --> AMI=0.206, ARI=0.219
# eps=3.50, T=1.70, grid=32x32, DBSCAN=0.25/10 --> AMI=-0.001, ARI=-0.001
# eps=3.50, T=1.70, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.70, grid=48x48, DBSCAN=0.15/5 --> AMI=0.546, ARI=0.346
# eps=3.50, T=1.70, grid=48x48, DBSCAN=0.15/10 --> AMI=0.317, ARI=0.078
# eps=3.50, T=1.70, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=1.70, grid=48x48, DBSCAN=0.2/5 --> AMI=0.262, ARI=0.107
# eps=3.50, T=1.70, grid=48x48, DBSCAN=0.2/10 --> AMI=0.714, ARI=0.757
# eps=3.50, T=1.70, grid=48x48, DBSCAN=0.2/15 --> AMI=0.080, ARI=0.012
# eps=3.50, T=1.70, grid=48x48, DBSCAN=0.25/5 --> AMI=0.077, ARI=0.025
# eps=3.50, T=1.70, grid=48x48, DBSCAN=0.25/10 --> AMI=0.154, ARI=0.057
# eps=3.50, T=1.70, grid=48x48, DBSCAN=0.25/15 --> AMI=0.804, ARI=0.869
# eps=3.50, T=1.70, grid=64x64, DBSCAN=0.15/5 --> AMI=0.771, ARI=0.660
# eps=3.50, T=1.70, grid=64x64, DBSCAN=0.15/10 --> AMI=0.677, ARI=0.341
# eps=3.50, T=1.70, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=3.50, T=1.70, grid=64x64, DBSCAN=0.2/5 --> AMI=0.100, ARI=0.014
# eps=3.50, T=1.70, grid=64x64, DBSCAN=0.2/10 --> AMI=0.521, ARI=0.260
# eps=3.50, T=1.70, grid=64x64, DBSCAN=0.2/15 --> AMI=0.713, ARI=0.433
# eps=3.50, T=1.70, grid=64x64, DBSCAN=0.25/5 --> AMI=0.025, ARI=0.004
# eps=3.50, T=1.70, grid=64x64, DBSCAN=0.25/10 --> AMI=0.082, ARI=0.016
# eps=3.50, T=1.70, grid=64x64, DBSCAN=0.25/15 --> AMI=0.460, ARI=0.235
# eps=3.50, T=2.00, grid=32x32, DBSCAN=0.15/5 --> AMI=0.039, ARI=0.008
# eps=3.50, T=2.00, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=3.50, T=2.00, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=2.00, grid=32x32, DBSCAN=0.2/5 --> AMI=0.272, ARI=0.283
# eps=3.50, T=2.00, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=3.50, T=2.00, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=2.00, grid=32x32, DBSCAN=0.25/5 --> AMI=0.064, ARI=0.069
# eps=3.50, T=2.00, grid=32x32, DBSCAN=0.25/10 --> AMI=-0.003, ARI=-0.005
# eps=3.50, T=2.00, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=2.00, grid=48x48, DBSCAN=0.15/5 --> AMI=0.668, ARI=0.532
# eps=3.50, T=2.00, grid=48x48, DBSCAN=0.15/10 --> AMI=0.345, ARI=0.083
# eps=3.50, T=2.00, grid=48x48, DBSCAN=0.15/15 --> AMI=0.081, ARI=0.067
# eps=3.50, T=2.00, grid=48x48, DBSCAN=0.2/5 --> AMI=0.263, ARI=0.106
# eps=3.50, T=2.00, grid=48x48, DBSCAN=0.2/10 --> AMI=0.723, ARI=0.763
# eps=3.50, T=2.00, grid=48x48, DBSCAN=0.2/15 --> AMI=0.547, ARI=0.277
# eps=3.50, T=2.00, grid=48x48, DBSCAN=0.25/5 --> AMI=0.055, ARI=0.016
# eps=3.50, T=2.00, grid=48x48, DBSCAN=0.25/10 --> AMI=0.161, ARI=0.070
# eps=3.50, T=2.00, grid=48x48, DBSCAN=0.25/15 --> AMI=0.826, ARI=0.895
# eps=3.50, T=2.00, grid=64x64, DBSCAN=0.15/5 --> AMI=0.680, ARI=0.365
# eps=3.50, T=2.00, grid=64x64, DBSCAN=0.15/10 --> AMI=0.800, ARI=0.529
# eps=3.50, T=2.00, grid=64x64, DBSCAN=0.15/15 --> AMI=0.894, ARI=0.930
# eps=3.50, T=2.00, grid=64x64, DBSCAN=0.2/5 --> AMI=0.070, ARI=0.005
# eps=3.50, T=2.00, grid=64x64, DBSCAN=0.2/10 --> AMI=0.404, ARI=0.093
# eps=3.50, T=2.00, grid=64x64, DBSCAN=0.2/15 --> AMI=0.765, ARI=0.523
# eps=3.50, T=2.00, grid=64x64, DBSCAN=0.25/5 --> AMI=0.019, ARI=0.001
# eps=3.50, T=2.00, grid=64x64, DBSCAN=0.25/10 --> AMI=0.051, ARI=0.006
# eps=3.50, T=2.00, grid=64x64, DBSCAN=0.25/15 --> AMI=0.369, ARI=0.103
# eps=3.50, T=2.50, grid=32x32, DBSCAN=0.15/5 --> AMI=0.042, ARI=0.009
# eps=3.50, T=2.50, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=3.50, T=2.50, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=2.50, grid=32x32, DBSCAN=0.2/5 --> AMI=0.318, ARI=0.326
# eps=3.50, T=2.50, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=3.50, T=2.50, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=2.50, grid=32x32, DBSCAN=0.25/5 --> AMI=0.288, ARI=0.313
# eps=3.50, T=2.50, grid=32x32, DBSCAN=0.25/10 --> AMI=-0.001, ARI=-0.001
# eps=3.50, T=2.50, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=3.50, T=2.50, grid=48x48, DBSCAN=0.15/5 --> AMI=0.682, ARI=0.501
# eps=3.50, T=2.50, grid=48x48, DBSCAN=0.15/10 --> AMI=0.637, ARI=0.320
# eps=3.50, T=2.50, grid=48x48, DBSCAN=0.15/15 --> AMI=0.891, ARI=0.934
# eps=3.50, T=2.50, grid=48x48, DBSCAN=0.2/5 --> AMI=0.113, ARI=0.020
# eps=3.50, T=2.50, grid=48x48, DBSCAN=0.2/10 --> AMI=0.664, ARI=0.421
# eps=3.50, T=2.50, grid=48x48, DBSCAN=0.2/15 --> AMI=0.689, ARI=0.462
# eps=3.50, T=2.50, grid=48x48, DBSCAN=0.25/5 --> AMI=0.021, ARI=0.004
# eps=3.50, T=2.50, grid=48x48, DBSCAN=0.25/10 --> AMI=0.087, ARI=0.019
# eps=3.50, T=2.50, grid=48x48, DBSCAN=0.25/15 --> AMI=0.525, ARI=0.300
# eps=3.50, T=2.50, grid=64x64, DBSCAN=0.15/5 --> AMI=0.570, ARI=0.152
# eps=3.50, T=2.50, grid=64x64, DBSCAN=0.15/10 --> AMI=0.908, ARI=0.843
# eps=3.50, T=2.50, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=3.50, T=2.50, grid=64x64, DBSCAN=0.2/5 --> AMI=0.027, ARI=0.001
# eps=3.50, T=2.50, grid=64x64, DBSCAN=0.2/10 --> AMI=0.336, ARI=0.053
# eps=3.50, T=2.50, grid=64x64, DBSCAN=0.2/15 --> AMI=0.781, ARI=0.551
# eps=3.50, T=2.50, grid=64x64, DBSCAN=0.25/5 --> AMI=0.011, ARI=0.001
# eps=3.50, T=2.50, grid=64x64, DBSCAN=0.25/10 --> AMI=0.040, ARI=0.002
# eps=3.50, T=2.50, grid=64x64, DBSCAN=0.25/15 --> AMI=0.300, ARI=0.046
# eps=4.00, T=1.00, grid=32x32, DBSCAN=0.15/5 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.00, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.00, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.00, grid=32x32, DBSCAN=0.2/5 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.00, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.00, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.00, grid=32x32, DBSCAN=0.25/5 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.00, grid=32x32, DBSCAN=0.25/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.00, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.00, grid=48x48, DBSCAN=0.15/5 --> AMI=0.086, ARI=0.019
# eps=4.00, T=1.00, grid=48x48, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.00, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.00, grid=48x48, DBSCAN=0.2/5 --> AMI=0.480, ARI=0.499
# eps=4.00, T=1.00, grid=48x48, DBSCAN=0.2/10 --> AMI=0.074, ARI=0.027
# eps=4.00, T=1.00, grid=48x48, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.00, grid=48x48, DBSCAN=0.25/5 --> AMI=0.252, ARI=0.274
# eps=4.00, T=1.00, grid=48x48, DBSCAN=0.25/10 --> AMI=-0.004, ARI=-0.012
# eps=4.00, T=1.00, grid=48x48, DBSCAN=0.25/15 --> AMI=0.147, ARI=0.057
# eps=4.00, T=1.00, grid=64x64, DBSCAN=0.15/5 --> AMI=0.390, ARI=0.122
# eps=4.00, T=1.00, grid=64x64, DBSCAN=0.15/10 --> AMI=0.541, ARI=0.208
# eps=4.00, T=1.00, grid=64x64, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.00, grid=64x64, DBSCAN=0.2/5 --> AMI=0.284, ARI=0.122
# eps=4.00, T=1.00, grid=64x64, DBSCAN=0.2/10 --> AMI=0.314, ARI=0.022
# eps=4.00, T=1.00, grid=64x64, DBSCAN=0.2/15 --> AMI=0.396, ARI=0.144
# eps=4.00, T=1.00, grid=64x64, DBSCAN=0.25/5 --> AMI=0.044, ARI=0.012
# eps=4.00, T=1.00, grid=64x64, DBSCAN=0.25/10 --> AMI=0.113, ARI=0.041
# eps=4.00, T=1.00, grid=64x64, DBSCAN=0.25/15 --> AMI=0.724, ARI=0.795
# eps=4.00, T=1.50, grid=32x32, DBSCAN=0.15/5 --> AMI=0.009, ARI=0.002
# eps=4.00, T=1.50, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.50, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.50, grid=32x32, DBSCAN=0.2/5 --> AMI=0.088, ARI=0.089
# eps=4.00, T=1.50, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.50, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.50, grid=32x32, DBSCAN=0.25/5 --> AMI=-0.004, ARI=-0.007
# eps=4.00, T=1.50, grid=32x32, DBSCAN=0.25/10 --> AMI=-0.001, ARI=-0.001
# eps=4.00, T=1.50, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.50, grid=48x48, DBSCAN=0.15/5 --> AMI=0.486, ARI=0.299
# eps=4.00, T=1.50, grid=48x48, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.50, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.50, grid=48x48, DBSCAN=0.2/5 --> AMI=0.284, ARI=0.117
# eps=4.00, T=1.50, grid=48x48, DBSCAN=0.2/10 --> AMI=0.746, ARI=0.788
# eps=4.00, T=1.50, grid=48x48, DBSCAN=0.2/15 --> AMI=0.370, ARI=0.133
# eps=4.00, T=1.50, grid=48x48, DBSCAN=0.25/5 --> AMI=0.099, ARI=0.033
# eps=4.00, T=1.50, grid=48x48, DBSCAN=0.25/10 --> AMI=0.180, ARI=0.066
# eps=4.00, T=1.50, grid=48x48, DBSCAN=0.25/15 --> AMI=0.824, ARI=0.885
# eps=4.00, T=1.50, grid=64x64, DBSCAN=0.15/5 --> AMI=0.746, ARI=0.701
# eps=4.00, T=1.50, grid=64x64, DBSCAN=0.15/10 --> AMI=0.654, ARI=0.296
# eps=4.00, T=1.50, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=4.00, T=1.50, grid=64x64, DBSCAN=0.2/5 --> AMI=0.110, ARI=0.017
# eps=4.00, T=1.50, grid=64x64, DBSCAN=0.2/10 --> AMI=0.543, ARI=0.325
# eps=4.00, T=1.50, grid=64x64, DBSCAN=0.2/15 --> AMI=0.716, ARI=0.442
# eps=4.00, T=1.50, grid=64x64, DBSCAN=0.25/5 --> AMI=0.032, ARI=0.006
# eps=4.00, T=1.50, grid=64x64, DBSCAN=0.25/10 --> AMI=0.077, ARI=0.014
# eps=4.00, T=1.50, grid=64x64, DBSCAN=0.25/15 --> AMI=0.513, ARI=0.303
# eps=4.00, T=1.70, grid=32x32, DBSCAN=0.15/5 --> AMI=0.009, ARI=0.002
# eps=4.00, T=1.70, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.70, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.70, grid=32x32, DBSCAN=0.2/5 --> AMI=0.155, ARI=0.149
# eps=4.00, T=1.70, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.70, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.70, grid=32x32, DBSCAN=0.25/5 --> AMI=0.286, ARI=0.335
# eps=4.00, T=1.70, grid=32x32, DBSCAN=0.25/10 --> AMI=-0.001, ARI=-0.001
# eps=4.00, T=1.70, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.70, grid=48x48, DBSCAN=0.15/5 --> AMI=0.506, ARI=0.314
# eps=4.00, T=1.70, grid=48x48, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.70, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=1.70, grid=48x48, DBSCAN=0.2/5 --> AMI=0.262, ARI=0.114
# eps=4.00, T=1.70, grid=48x48, DBSCAN=0.2/10 --> AMI=0.752, ARI=0.780
# eps=4.00, T=1.70, grid=48x48, DBSCAN=0.2/15 --> AMI=0.370, ARI=0.133
# eps=4.00, T=1.70, grid=48x48, DBSCAN=0.25/5 --> AMI=0.094, ARI=0.031
# eps=4.00, T=1.70, grid=48x48, DBSCAN=0.25/10 --> AMI=0.183, ARI=0.075
# eps=4.00, T=1.70, grid=48x48, DBSCAN=0.25/15 --> AMI=0.755, ARI=0.854
# eps=4.00, T=1.70, grid=64x64, DBSCAN=0.15/5 --> AMI=0.727, ARI=0.588
# eps=4.00, T=1.70, grid=64x64, DBSCAN=0.15/10 --> AMI=0.638, ARI=0.291
# eps=4.00, T=1.70, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=4.00, T=1.70, grid=64x64, DBSCAN=0.2/5 --> AMI=0.103, ARI=0.015
# eps=4.00, T=1.70, grid=64x64, DBSCAN=0.2/10 --> AMI=0.519, ARI=0.285
# eps=4.00, T=1.70, grid=64x64, DBSCAN=0.2/15 --> AMI=0.745, ARI=0.512
# eps=4.00, T=1.70, grid=64x64, DBSCAN=0.25/5 --> AMI=0.027, ARI=0.004
# eps=4.00, T=1.70, grid=64x64, DBSCAN=0.25/10 --> AMI=0.068, ARI=0.011
# eps=4.00, T=1.70, grid=64x64, DBSCAN=0.25/15 --> AMI=0.458, ARI=0.249
# eps=4.00, T=2.00, grid=32x32, DBSCAN=0.15/5 --> AMI=0.016, ARI=0.004
# eps=4.00, T=2.00, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=2.00, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=2.00, grid=32x32, DBSCAN=0.2/5 --> AMI=0.212, ARI=0.219
# eps=4.00, T=2.00, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=2.00, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=2.00, grid=32x32, DBSCAN=0.25/5 --> AMI=0.253, ARI=0.285
# eps=4.00, T=2.00, grid=32x32, DBSCAN=0.25/10 --> AMI=-0.001, ARI=-0.001
# eps=4.00, T=2.00, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=2.00, grid=48x48, DBSCAN=0.15/5 --> AMI=0.562, ARI=0.347
# eps=4.00, T=2.00, grid=48x48, DBSCAN=0.15/10 --> AMI=0.385, ARI=0.097
# eps=4.00, T=2.00, grid=48x48, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=2.00, grid=48x48, DBSCAN=0.2/5 --> AMI=0.204, ARI=0.089
# eps=4.00, T=2.00, grid=48x48, DBSCAN=0.2/10 --> AMI=0.760, ARI=0.818
# eps=4.00, T=2.00, grid=48x48, DBSCAN=0.2/15 --> AMI=0.418, ARI=0.143
# eps=4.00, T=2.00, grid=48x48, DBSCAN=0.25/5 --> AMI=0.055, ARI=0.020
# eps=4.00, T=2.00, grid=48x48, DBSCAN=0.25/10 --> AMI=0.120, ARI=0.047
# eps=4.00, T=2.00, grid=48x48, DBSCAN=0.25/15 --> AMI=0.741, ARI=0.800
# eps=4.00, T=2.00, grid=64x64, DBSCAN=0.15/5 --> AMI=0.662, ARI=0.301
# eps=4.00, T=2.00, grid=64x64, DBSCAN=0.15/10 --> AMI=0.741, ARI=0.409
# eps=4.00, T=2.00, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=4.00, T=2.00, grid=64x64, DBSCAN=0.2/5 --> AMI=0.073, ARI=0.009
# eps=4.00, T=2.00, grid=64x64, DBSCAN=0.2/10 --> AMI=0.396, ARI=0.125
# eps=4.00, T=2.00, grid=64x64, DBSCAN=0.2/15 --> AMI=0.690, ARI=0.377
# eps=4.00, T=2.00, grid=64x64, DBSCAN=0.25/5 --> AMI=0.019, ARI=0.002
# eps=4.00, T=2.00, grid=64x64, DBSCAN=0.25/10 --> AMI=0.046, ARI=0.003
# eps=4.00, T=2.00, grid=64x64, DBSCAN=0.25/15 --> AMI=0.349, ARI=0.066
# eps=4.00, T=2.50, grid=32x32, DBSCAN=0.15/5 --> AMI=0.039, ARI=0.008
# eps=4.00, T=2.50, grid=32x32, DBSCAN=0.15/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=2.50, grid=32x32, DBSCAN=0.15/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=2.50, grid=32x32, DBSCAN=0.2/5 --> AMI=0.354, ARI=0.365
# eps=4.00, T=2.50, grid=32x32, DBSCAN=0.2/10 --> AMI=0.000, ARI=0.000
# eps=4.00, T=2.50, grid=32x32, DBSCAN=0.2/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=2.50, grid=32x32, DBSCAN=0.25/5 --> AMI=0.222, ARI=0.243
# eps=4.00, T=2.50, grid=32x32, DBSCAN=0.25/10 --> AMI=-0.001, ARI=-0.001
# eps=4.00, T=2.50, grid=32x32, DBSCAN=0.25/15 --> AMI=0.000, ARI=0.000
# eps=4.00, T=2.50, grid=48x48, DBSCAN=0.15/5 --> AMI=0.759, ARI=0.657
# eps=4.00, T=2.50, grid=48x48, DBSCAN=0.15/10 --> AMI=0.582, ARI=0.265
# eps=4.00, T=2.50, grid=48x48, DBSCAN=0.15/15 --> AMI=0.581, ARI=0.620
# eps=4.00, T=2.50, grid=48x48, DBSCAN=0.2/5 --> AMI=0.123, ARI=0.023
# eps=4.00, T=2.50, grid=48x48, DBSCAN=0.2/10 --> AMI=0.608, ARI=0.343
# eps=4.00, T=2.50, grid=48x48, DBSCAN=0.2/15 --> AMI=0.677, ARI=0.414
# eps=4.00, T=2.50, grid=48x48, DBSCAN=0.25/5 --> AMI=0.018, ARI=0.003
# eps=4.00, T=2.50, grid=48x48, DBSCAN=0.25/10 --> AMI=0.094, ARI=0.033
# eps=4.00, T=2.50, grid=48x48, DBSCAN=0.25/15 --> AMI=0.531, ARI=0.286
# eps=4.00, T=2.50, grid=64x64, DBSCAN=0.15/5 --> AMI=0.559, ARI=0.140
# eps=4.00, T=2.50, grid=64x64, DBSCAN=0.15/10 --> AMI=0.912, ARI=0.865
# eps=4.00, T=2.50, grid=64x64, DBSCAN=0.15/15 --> AMI=1.000, ARI=1.000
# eps=4.00, T=2.50, grid=64x64, DBSCAN=0.2/5 --> AMI=0.039, ARI=0.003
# eps=4.00, T=2.50, grid=64x64, DBSCAN=0.2/10 --> AMI=0.352, ARI=0.059
# eps=4.00, T=2.50, grid=64x64, DBSCAN=0.2/15 --> AMI=0.785, ARI=0.555
# eps=4.00, T=2.50, grid=64x64, DBSCAN=0.25/5 --> AMI=0.005, ARI=0.000
# eps=4.00, T=2.50, grid=64x64, DBSCAN=0.25/10 --> AMI=0.033, ARI=0.002
# eps=4.00, T=2.50, grid=64x64, DBSCAN=0.25/15 --> AMI=0.293, ARI=0.041
#
# === BEST PARAMETERS (by ARI) ===
# Epsilon (privacy):      0.3
# Threshold T:            1.0
# Grid size:              64 x 64
# DBSCAN eps / min_samp:  0.15 / 15
# Best ARI:               1.0000
# AMI at best ARI:        1.0000

# %%
# PLOT for eps = 2and T = 1 

eps_priv = 2
T = 1
nx = ny = 64  

# Build grid
H, xs, ys = make_grid(
    X,
    (X[:,0].min(), X[:,0].max()),
    (X[:,1].min(), X[:,1].max()),
    n_x=nx, n_y=ny
)

#  Add Laplace noise
noisy, _ = laplace_mech(H, epsilon=eps_priv, clip_zero=True)

# Extract spans
spans = spans_from_noisy(noisy, threshold_T=T)


# Convert spans to world boxes
spans_world = boxes_to_world(spans, xs, ys)

# Predicted labels from DP spans
y_pred = assign_labels_from_spans(X, spans_world)

# Ground-truth via DBSCAN 
db_eps = 0.20
db_min = 10
y_true = DBSCAN(eps=db_eps, min_samples=db_min).fit_predict(X)

# Only compare non-noise points on both sides
idx = (y_true != -1) & (y_pred != -1)

if idx.any():
    AMI = adjusted_mutual_info_score(y_true[idx], y_pred[idx])
    ARI = adjusted_rand_score(y_true[idx], y_pred[idx])
else:
    AMI = 0.0
    ARI = 0.0

# 4) Plot DP noisy histogram + spans
plt.figure(figsize=(6,5))
plt.imshow(noisy.T, origin="lower", cmap="viridis")

for (x1, y1, x2, y2) in spans:
    plt.plot(
        [x1, x2, x2, x1, x1],
        [y1, y1, y2, y2, y1],
        "r-", lw=2
    )

plt.axis("off")
plt.show()
